# %%
import pandas as pd

# %%
doencas = pd.read_csv('./DistribuicaoCloroquinaOseltamivir.csv', sep=';')
#Distribuição Cloroquina e Oseltamivir 'http://dados.gov.br/dataset/distribuicao-de-medicamentos-covid-19/resource/b2bbb02c-1d0c-4a41-909e-ee27a93a11cc'

# %%
doencas#atualizado 17/Agosto/2020
# Out:
#            REGIAO              UF         DESTINATARIO  LOCALIDADE  \
# 0           NORTE            ACRE                  SES   BOA VISTA
# 1        NORDESTE           CEARA                  SES   FORTALEZA
# 2         SUDESTE  ESPIRITO SANTO                  SES     VITORIA
# 3    CENTRO-OESTE           GOIAS                  SES     GOIANIA
# 4    CENTRO-OESTE     MATO GROSSO                  SES      CUIABA
# ..            ...             ...                  ...         ...
# 556         NORTE         RORAIMA        DSEI YANOMAMI   BOA VISTA
# 557         NORTE            Acre       DSEI RIO PURUS  RIO BRANCO
# 558  CENTRO-OESTE     MATO GROSSO  DSEI KAIAPO COLIDER     COLIDER
# 559           SUL          PARANA                  SES    CURITIBA
# 560         NORTE            PARA     DSEI RIO TAPAJOS    ITAITUBA
#
#                               ITEM PROGRAMA DE SAUDE QUANTIDADE  \
# 0    DIFOSFATO DE CLOROQUINA 150MG          COVID-19    79000,0
# ...

# %%
doencas['PROGRAMA DE SAUDE']. value_counts ()#retorna a coluna programa de saude e o quanto se repete
# Out:
# INFLUENZA    360
# COVID-19     123
# MALARIA       78
# Name: PROGRAMA DE SAUDE, dtype: int64

# %%
ndoencas = velointernet_df['PROGRAMA DE SAUDE']. value_counts ()# salva em doencas

# %%
ndoencas. plot ( kind = 'bar' )# retorna um grafico

# %%
#observamos que a INFLUENZA (Uma infecção viral comum que pode ser fatal, especialmente em grupos de alto risco.) 
#tem um maior numero de distribuicao baseando nos pedidos

# %%
CLOROQUINA = doencas[doencas['ITEM']=='DIFOSFATO DE CLOROQUINA 150MG']#retorna todos itens que sao o medicamento
CLOROQUINA
# Out:
#            REGIAO              UF         DESTINATARIO  LOCALIDADE  \
# 0           NORTE            ACRE                  SES   BOA VISTA
# 1        NORDESTE           CEARA                  SES   FORTALEZA
# 2         SUDESTE  ESPIRITO SANTO                  SES     VITORIA
# 3    CENTRO-OESTE           GOIAS                  SES     GOIANIA
# 4    CENTRO-OESTE     MATO GROSSO                  SES      CUIABA
# ..            ...             ...                  ...         ...
# 556         NORTE         RORAIMA        DSEI YANOMAMI   BOA VISTA
# 557         NORTE            Acre       DSEI RIO PURUS  RIO BRANCO
# 558  CENTRO-OESTE     MATO GROSSO  DSEI KAIAPO COLIDER     COLIDER
# 559           SUL          PARANA                  SES    CURITIBA
# 560         NORTE            PARA     DSEI RIO TAPAJOS    ITAITUBA
#
#                               ITEM PROGRAMA DE SAUDE QUANTIDADE  \
# 0    DIFOSFATO DE CLOROQUINA 150MG          COVID-19    79000,0
# ...

# %%
doencaCloroquina = CLOROQUINA['PROGRAMA DE SAUDE'].value_counts ()#retorna os medicamentos juntando as doencas
doencaCloroquina
# Out:
# COVID-19    123
# MALARIA      78
# Name: PROGRAMA DE SAUDE, dtype: int64

# %%
#observamos que a CLOROQUINA `e usada para tratamento de malaria nao somente de covid-19
#Quase 39% das cloroquinas sao destinada a malaria

# %%
doencaCloroquina.plot(kind = 'bar')#referente a amostra anterior

# %%
covid = doencas[doencas['PROGRAMA DE SAUDE']=='COVID-19']#retorna tudo filtrando por covid
covid
# Out:
#            REGIAO                  UF    DESTINATARIO  \
# 0           NORTE                ACRE             SES
# 1        NORDESTE               CEARA             SES
# 2         SUDESTE      ESPIRITO SANTO             SES
# 3    CENTRO-OESTE               GOIAS             SES
# 4    CENTRO-OESTE         MATO GROSSO             SES
# ..            ...                 ...             ...
# 125         NORTE             RORAIMA  SAUDE INDIGENA
# 126         NORTE             RORAIMA  SAUDE INDIGENA
# 127         NORTE             RORAIMA  SAUDE INDIGENA
# 128  CENTRO-OESTE  MATO GROSSO DO SUL             SMS
# 129           SUL      SANTA CATARINA             SMS
#
#                                 LOCALIDADE                           ITEM  \
# 0                                BOA VISTA  DIFOSFATO DE CLOROQUINA 150MG
# 1                                FORTALEZA  DIFOSFATO DE CLOROQUINA 150MG
# 2                                  VITORIA  DIFOSFATO DE CLOROQUINA 150MG
# ...

# %%
andamentoCovid = covid[covid['STATUS']=='EM ANDAMENTO']['LOCALIDADE'].value_counts ()
andamentoCovid#retorna todos os pedidos em andamento por localidade
# Out:
# PORTO VELHO      2
# PALMAS           2
# VITORIA          2
# CUIABA           2
# CAMPO GRANDE     2
# BOA VISTA        2
# FORTALEZA        1
# NATAL            1
# TERESINA         1
# MARITUBA         1
# FLORIANOPOLIS    1
# RECIFE           1
# MANAUS           1
# GOIANIA          1
# PORTO ALEGRE     1
# MACEIO           1
# Name: LOCALIDADE, dtype: int64

# %%
#percebemos que existema mais de um pedido em andamento para a mesma localidades acarretando assim um maior numero de doentes

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-e298b1706223> in <module>
# ----> 1 CLOROQUINA[CLOROQUINA['LOCALIDADE']=='FORTALEZA'][sum(['QUANTIDADE'])]
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Out:
#   File "<ipython-input-136-c6e5c9fb1e5f>", line 1
#     sum(doencas.'QUANTIDADE')
#                 ^
# SyntaxError: invalid syntax
